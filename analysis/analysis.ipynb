# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas
from datetime import *

# %%
# !rm button.csv*
# !wget http://tcial.org/the-button/button.csv
now = datetime.utcnow()
# Out:
# --2015-04-13 02:21:42--  http://tcial.org/the-button/button.csv
# Resolving tcial.org...
# 93.92.148.4
# Connecting to tcial.org|93.92.148.4|:80...
# connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 17400787 (17M) [text/plain]
# Saving to: 'button.csv'
#
#  0% [                                       ] 0           --.-K/s
#  0% [                                       ] 15,160      73.6KB/s
#  0% [                                       ] 70,072       169KB/s
#  1% [                                       ] 272,824      440KB/s
#  3% [>                                      ] 530,488      642KB/s
#  4% [>                                      ] 789,560      765KB/s
#  5% [=>                                     ] 1,021,880    826KB/s
#  7% [=>                                     ] 1,272,504    882KB/s
#  8% [==>                                    ] 1,532,984    930KB/s
# 10% [===>                                   ] 1,790,648    966KB/s
# 11% [===>                                   ] 2,045,496    993KB/s
# 13% [====>                                  ] 2,298,936   1015KB/s
# 14% [====>                                  ] 2,558,008   1.01MB/s
# 16% [=====>                                 ] 2,817,080   1.03MB/s
# 17% [=====>                                 ] 3,077,560   1.04MB/s
# 19% [======>                                ] 3,339,448   1.06MB/s  eta 13s
# 20% [=======>                               ] 3,570,360   1.12MB/s  eta 13s
# 22% [=======>                               ] 3,830,840   1.17MB/s  eta 13s
# 23% [========>                              ] 4,091,320   1.21MB/s  eta 13s
# 25% [========>                              ] 4,350,392   1.21MB/s  eta 13s
# 26% [=========>                             ] 4,608,056   1.21MB/s  eta 11s
# 27% [=========>                             ] 4,869,944   1.21MB/s  eta 11s
# 29% [==========>                            ] 5,130,424   1.22MB/s  eta 11s
# 30% [===========>                           ] 5,389,496   1.22MB/s  eta 11s
# 32% [===========>                           ] 5,651,384   1.22MB/s  eta 11s
# 33% [============>                          ] 5,910,456   1.22MB/s  eta 10s
# 35% [============>                          ] 6,138,552   1.22MB/s  eta 10s
# 36% [=============>                         ] 6,399,032   1.22MB/s  eta 10s
# 38% [=============>                         ] 6,659,512   1.22MB/s  eta 10s
# 39% [==============>                        ] 6,919,992   1.22MB/s  eta 10s
# 41% [===============>                       ] 7,180,472   1.22MB/s  eta 9s
# 42% [===============>                       ] 7,440,952   1.22MB/s  eta 9s
# 44% [================>                      ] 7,700,024   1.23MB/s  eta 9s
# 45% [================>                      ] 7,961,912   1.23MB/s  eta 9s
# 47% [=================>                     ] 8,222,392   1.23MB/s  eta 9s
# 48% [==================>                    ] 8,481,464   1.23MB/s  eta 7s
# 50% [==================>                    ] 8,706,744   1.22MB/s  eta 7s
# 51% [===================>                   ] 8,967,224   1.22MB/s  eta 7s
# 53% [===================>                   ] 9,224,888   1.22MB/s  eta 7s
# 54% [====================>                  ] 9,485,368   1.22MB/s  eta 7s
# 56% [====================>                  ] 9,745,848   1.22MB/s  eta 6s
# 57% [=====================>                 ] 10,004,920  1.22MB/s  eta 6s
# 58% [======================>                ] 10,263,992  1.23MB/s  eta 6s
# 60% [======================>                ] 10,527,288  1.23MB/s  eta 6s
# 61% [=======================>               ] 10,787,768  1.23MB/s  eta 6s
# 63% [=======================>               ] 11,048,248  1.23MB/s  eta 5s
# 64% [========================>              ] 11,269,304  1.21MB/s  eta 5s
# 66% [========================>              ] 11,531,192  1.21MB/s  eta 5s
# 67% [=========================>             ] 11,794,488  1.21MB/s  eta 5s
# 69% [==========================>            ] 12,052,152  1.21MB/s  eta 5s
# 70% [==========================>            ] 12,312,632  1.21MB/s  eta 4s
# 72% [===========================>           ] 12,574,520  1.21MB/s  eta 4s
# 73% [===========================>           ] 12,829,368  1.22MB/s  eta 4s
# 75% [============================>          ] 13,089,848  1.22MB/s  eta 4s
# 76% [============================>          ] 13,350,328  1.23MB/s  eta 4s
# 78% [=============================>         ] 13,610,808  1.23MB/s  eta 3s
# 79% [==============================>        ] 13,840,312  1.22MB/s  eta 3s
# 81% [==============================>        ] 14,100,792  1.22MB/s  eta 3s
# 82% [===============================>       ] 14,362,680  1.22MB/s  eta 3s
# 84% [===============================>       ] 14,621,752  1.21MB/s  eta 3s
# 85% [================================>      ] 14,879,416  1.21MB/s  eta 2s
# 86% [================================>      ] 15,130,040  1.21MB/s  eta 2s
# 88% [=================================>     ] 15,387,704  1.22MB/s  eta 2s
# 89% [==================================>    ] 15,648,184  1.22MB/s  eta 2s
# 91% [==================================>    ] 15,908,664  1.22MB/s  eta 2s
# 92% [===================================>   ] 16,167,736  1.22MB/s  eta 1s
# 94% [===================================>   ] 16,387,384  1.21MB/s  eta 1s
# 95% [====================================>  ] 16,646,456  1.21MB/s  eta 1s
# 97% [====================================>  ] 16,905,528  1.21MB/s  eta 1s
# 98% [=====================================> ] 17,167,416  1.21MB/s  eta 1s
# 100%[======================================>] 17,400,787  1.21MB/s   in 14s
#
# 2015-04-13 02:21:56 (1.18 MB/s) - 'button.csv' saved [17400787/17400787]

# %%
C = [
    'red',
    'orange',
    'yellow',
    'green',
    'blue',
    'purple',
]

lb = [
    2,
    12,
    22,
    32,
    42,
    52,
]

hb = [
    12,
    22,
    32,
    42,
    52,
    62,
]

def slice_presses(left, right=None):
    if right is None:
        right = timedelta()
    mask = ((now - left) < presses[:, 0]) * ((now - right) > presses[:, 0])
    return presses[mask]

mapl = lambda *a, **kw: list(map(*a, **kw))

ticks = array(pandas.read_csv('button.csv').values, dtype=object)

for i in ticks:
    i[0] = datetime.utcfromtimestamp(i[0])

# %%
presses = []

prev_tick = ticks[0, 2]
for i in ticks:
    if i[2] >= prev_tick:
        presses.append([i[0], prev_tick])
    
    prev_tick = i[2]
presses = array(presses)

# %%
def get_periods(period_length):
    period = []
    periods = []
    period_start = presses[0, 0]
    prev_time = presses[0, 0]
    for time, timer in presses:
        period.append([time, timer])
        if time - prev_time > timedelta(minutes=1):
            period = []
            period_start = time
        if time - period_start > period_length:
            periods.append(array(period))
            period = []
            period_start = time
        prev_time = time
    return periods

# %%
def get_aggregates(periods, fs):
    aggregates = []
    for period in periods:
        a = array(period[:, 1], dtype=float)
        t = [period[0, 0]]
        for f in fs:
            t.append(f(a))
        aggregates.append(t)
    return array(aggregates)

# %%
periods = get_periods(timedelta(minutes=50))

X = get_aggregates(periods, [
    min, 
    lambda a: percentile(a, 25),
    median, 
    lambda a: percentile(a, 75),
    std,
])

hfmt = matplotlib.dates.DateFormatter('%m/%d %H:%M')
figure(figsize=(12, 7))
title('historical presses')
ylim((0, 60))

w = 3
plot(X[:, 0], X[:, 1], label='min', lw=w)
plot(X[:, 0], X[:, 2], label='25p', lw=w)
plot(X[:, 0], X[:, 3], label='median', lw=w)
plot(X[:, 0], X[:, 4], label='75p', lw=w)
plot(X[:, 0], X[:, 5], label='std', lw=w)

gca().xaxis.set_major_formatter(hfmt)
gcf().autofmt_xdate()
grid(True)
legend(bbox_to_anchor=(1, 1), loc=2)
xlabel('UTC')
savefig('all.png', bbox_inches='tight')

# %%
periods = get_periods(timedelta(minutes=6))

aggregates = get_aggregates(periods, [
    min, 
    lambda a: percentile(a, 25),
    median, 
    lambda a: percentile(a, 75),
    std,
])

X = aggregates[now - aggregates[:, 0] < timedelta(hours=24)]

hfmt = matplotlib.dates.DateFormatter('%m/%d %H:%M')
figure(figsize=(12, 7))
title('24h presses')
ylim((0, 60))

w = 3
plot(X[:, 0], X[:, 1], label='min',    lw=w)
plot(X[:, 0], X[:, 2], label='25p',    lw=w)
plot(X[:, 0], X[:, 3], label='median', lw=w)
plot(X[:, 0], X[:, 4], label='75p',    lw=w)
plot(X[:, 0], X[:, 5], label='std',    lw=w)

gca().xaxis.set_major_formatter(hfmt)
gcf().autofmt_xdate()
grid(True)
legend(bbox_to_anchor=(1, 1), loc=2)
xlabel('UTC')
savefig('24h.png', bbox_inches='tight')

# %%
def chist(x, **kw):
    if len(x) == 0:
        return
    hist(x, **kw)

# %%
X = presses[:, 1]

figure(figsize=(12, 7))

fr = min(X) // 5 *  5
b = list(range(fr, 62))
xlim((fr, 61))

for i in range(6):
    chist(X[(lb[i] <= X) * (X < hb[i])], bins=b, color=C[i])

ticks = array(range(fr, 61, 5))
gca().set_xticks(ticks + 0.5)
gca().set_xticklabels(mapl(str, ticks))

title('historical press distribution')
savefig('all_hist.png', bbox_inches='tight')

# %%
Y = slice_presses(timedelta(days=2), timedelta(days=1))[:, 1]
X = slice_presses(timedelta(days=1))[:, 1]

figure(figsize=(12, 7))

fr = min(hstack((X, Y))) // 5 *  5
b = list(range(fr, 62))
xlim((fr, 61))

for i in range(6):
    chist(X[(lb[i] <= X) * (X < hb[i])], bins=b, color=C[i], ec=C[i])
    chist(Y[(lb[i] <= Y) * (Y < hb[i])], bins=b, fill=False, lw=1)

ticks = array(range(fr, 61, 5))
gca().set_xticks(ticks + 0.5)
gca().set_xticklabels(mapl(str, ticks))

title('1d distribution (outlined is previous period)')
savefig('1d_hist.png', bbox_inches='tight')

# %%
Y = slice_presses(timedelta(hours=12), timedelta(hours=6))[:, 1]
X = slice_presses(timedelta(hours=6))[:, 1]

figure(figsize=(12, 7))

fr = min(hstack((X, Y))) // 5 *  5
b = list(range(fr, 62))
xlim((fr, 61))

for i in range(6):
    chist(X[(lb[i] <= X) * (X < hb[i])], bins=b, color=C[i], ec=C[i])
    chist(Y[(lb[i] <= Y) * (Y < hb[i])], bins=b, fill=False, lw=1)

ticks = array(range(fr, 61, 5))
gca().set_xticks(ticks + 0.5)
gca().set_xticklabels(mapl(str, ticks))

title('6h distribution (outlined is previous period)')
savefig('6h_hist.png', bbox_inches='tight')

# %%
X = slice_presses(timedelta(minutes=10))

Col = [
    'red',
    'orange',
    'yellow',
    'green',
    'blue',
    'purple',
]

figure(figsize=(12, 7))
ylim((0, 60))

for i in range(6):
    Y = X[(lb[i] <= X[:, 1]) * (X[:, 1] < hb[i])]
    for j, k in Y:
        axvline(j, ymin=k / 60, color=Col[i], lw=2)
        
for i in range(6):
    Y = X[(lb[i] <= X[:, 1]) * (X[:, 1] < hb[i])]
    plot(Y[:, 0], Y[:, 1], 'o', color=Col[i], ms=8)

hfmt = matplotlib.dates.DateFormatter('%m/%d %H:%M:%S')
gca().xaxis.set_major_formatter(hfmt)
gcf().autofmt_xdate()
grid(True)
xlabel('UTC')
title('10m presses')
savefig('10m_presses.png', bbox_inches='tight')

# %%
def get_colors(a):
    colors = [0] * 6;
    
    for i in range(6):
        colors[i] = sum(a[(a >= lb[i]) * (a < hb[i])])
    
    return array(colors)

# %%
X = []
period_length = 30
for i in range(3 * 24 * (60 // period_length), 0, -1):
    left = timedelta(minutes=i * period_length)
    right = timedelta(minutes=(i - 1) * period_length)
    t = hstack(([now - left], get_colors(slice_presses(left, right)[:, 1])))
    X.append(t)
X = array(X)
X = hstack((X, array([X[:, 1:].sum(1)]).T))


Y = array(X)
counts = array(Y[:, 7])
counts[counts == 0] = 1

for i in range(1, 7):
    Y[:, i] /= counts

    
figure(figsize=(12, 7))
grid(True)

hfmt = matplotlib.dates.DateFormatter('%m/%d %H:%M')
gca().xaxis.set_major_formatter(hfmt)
gcf().autofmt_xdate()

w = 6

for i in range(5, -1, -1):
    if sum(Y[:, 1 + i]) > 0:
        plot(Y[:, 0], Y[:, 1 + i], color='black',  lw=w)
        plot(Y[:, 0], Y[:, 1 + i], color=C[i], lw=w-1)

ylim((0, 1))
xlabel('UTC')
title('3d flair distribution')
savefig('3d_flair.png', bbox_inches='tight')

# %%
X = []
period_length = 20
for i in range(24 * (60 // period_length), 0, -1):
    left = timedelta(minutes=i * period_length)
    right = timedelta(minutes=(i - 1) * period_length)
    t = hstack(([now - left], get_colors(slice_presses(left, right)[:, 1])))
    X.append(t)
X = array(X)
X = hstack((X, array([X[:, 1:].sum(1)]).T))


Y = array(X)
counts = array(Y[:, 7])
counts[counts == 0] = 1

for i in range(1, 7):
    Y[:, i] /= counts

    
figure(figsize=(12, 7))
grid(True)

hfmt = matplotlib.dates.DateFormatter('%m/%d %H:%M')
gca().xaxis.set_major_formatter(hfmt)
gcf().autofmt_xdate()

w = 6

for i in range(5, -1, -1):
    if sum(Y[:, 1 + i]) > 0:
        plot(Y[:, 0], Y[:, 1 + i], color='black',  lw=w)
        plot(Y[:, 0], Y[:, 1 + i], color=C[i], lw=w-1)

ylim((0, 1))
xlabel('UTC')
title('24h flair distribution')
savefig('24h_flair.png', bbox_inches='tight')
